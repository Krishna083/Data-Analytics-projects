# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %%
# Import required libraries and read the dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\krish\\Data Analytics projects'

# %%
df = pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
# Check the first few samples, shape, info of the data and try to familiarize yourself with different features
df.sample(5)
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 10     IN   9000.0           92   828000.0  489000.0        0.85   704000.0
# 611    NC  13000.0           39   507000.0  106000.0        3.76  1906000.0
# 610    NY  51000.0           51  2601000.0  988000.0        2.23  5800000.0
# 200    NC  16000.0           42   672000.0   74000.0        1.41   948000.0
# 204    OR  43000.0           49  2107000.0  885000.0        1.35  2844000.0
#
#      year
# 10   1998
# 611  2012
# 610  2012
# 200  2002
# 204  2002

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
df.describe(include = 'all').T
# Out:
#             count unique  top freq         mean          std     min     25%  \
# state         626     44   GA   15          NaN          NaN     NaN     NaN
# numcol        626    NaN  NaN  NaN      60284.3      91077.1    2000    9000
# yieldpercol   626    NaN  NaN  NaN      62.0096      19.4588      19      48
# totalprod     626    NaN  NaN  NaN  4.16909e+06  6.88385e+06   84000  475000
# stocks        626    NaN  NaN  NaN  1.31886e+06  2.27296e+06    8000  143000
# priceperlb    626    NaN  NaN  NaN      1.40957     0.638599    0.49  0.9325
# prodvalue     626    NaN  NaN  NaN  4.71574e+06  7.97611e+06  162000  759250
# year          626    NaN  NaN  NaN      2004.86      4.31731    1998    2001
#
#                     50%          75%         max
# state               NaN          NaN         NaN
# numcol            26000        63750      510000
# yieldpercol          60           74         136
# totalprod     1.533e+06  4.17525e+06   4.641e+07
# ...

# %%
# Display the percentage distribution of the data in each year using the pie chart.
plt.figure(figsize = (7,7))
plt.pie(df.year.value_counts(),autopct = '%.1f%%',labels=df.year.value_counts().index)
plt.show()

# %%
# Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings
sns.displot(df['priceperlb'],bins = 20, kde = True )

# %% [markdown]
# # Observation - Most of the data lies between 0.5 - 1.7 (priceperlb). The data is skewed towards right side this means mean will shift to right side. As per the data, sales was very low after 2.6 priceperlb.

# %%
# Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

numcol = df['numcol']
prodvalue = df['prodvalue']
plt.xlabel("numcol")
plt.ylabel("prodvalue")
plt.scatter(numcol, prodvalue, color = 'red')
plt.show()

# %% [markdown]
# # Observation - There is a  positive relationship between variables numcol and prodvalue. If there is change in one variable the other variable also changes. There are some outliers in variable numcol.

# %%
#  Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings
plt.figure(figsize = (7,7))
sns.boxplot(data = df, x = 'year', y = 'prodvalue')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Observation - As per the data there are many outliers in it. There is positive relation between both the variables but not too strong. The prodvalue in initial years decreases and it started increasing in year 2002,3,4. Again there was decline in prodvalue in year 2005,6,7 and afterwards there was a good growth in later years. In the year 2010,11,12 the prodvalue was highest.

# %%
# Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')
plt.figure()
sns.pairplot(df[["numcol", "yieldpercol", "totalprod", "prodvalue","year"]], hue = "year", kind = "scatter", palette = "husl")
plt.show()

# %% [markdown]
# # Observation - The plots that they are have positive uptrend relationship with each other. The attributes numcol, totalprod, prodvalue clearly indicates an extreme long tail on the right. Presence of higher values. Yieldpercol should probably have a normal distribution. The constraints on the data collection may have skewed the distribution.

# %%
# Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue'
df.corr()
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  \
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567
# year         0.008709    -0.232092  -0.055556 -0.119602    0.693984
#
#              prodvalue      year
# numcol        0.912796  0.008709
# yieldpercol   0.278977 -0.232092
# totalprod     0.907236 -0.055556
# stocks        0.728560 -0.119602
# priceperlb   -0.089567  0.693984
# prodvalue     1.000000  0.139451
# year          0.139451  1.000000

# %%
plt.figure(figsize = (7,7))
sns.heatmap(df.corr(), annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Observation - The top 3 positive correlated pairs are - totalprod and numcol - 0.95, prodvalue and totalprod - 0.91, prodvalue and numcol- 0.91. The top 3 negative correlated pairs are - priceperlb and yieldpercol - -0.36, priceperlb and  stocks - -0.31, priceperlb and totalprod - -0.26
